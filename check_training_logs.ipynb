# %%
import tensorflow as tf

# Path to the event file on the remote machine
event_file = './logs/plugin_over_ft_tokentest_faster_without_logitshift_20epochs/events.out.tfevents.1728412233.ip-172-16-12-173.us-west-2.compute.internal.50122.0'

# Create an iterator for the event file
for event in tf.compat.v1.train.summary_iterator(event_file):
    for value in event.summary.value:
        if value.HasField('simple_value'):
            if(value.tag == 'train/loss'):
                print(f"Step: {event.step}, Tag: {value.tag}, Value: {value.simple_value}")
# Out:
# 2024-10-09 16:28:29.536709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-09 16:28:29.778569: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-09 16:28:29.780206: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-09 16:28:30.209364: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
